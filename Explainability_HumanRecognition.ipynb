# %%
# !pip install datamanager

# %%
# %matplotlib inline

import sys
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from collections import Counter
from collections import defaultdict

from sklearn.model_selection import train_test_split, cross_val_score

from sklearn.metrics import accuracy_score, f1_score, classification_report
from sklearn.metrics import roc_curve, auc, roc_auc_score

# %%
X_train = pd.read_csv('X_train_con_nomi.csv', header = 0)
y_train = pd.read_fwf('y_train.txt', header = None)
X_test = pd.read_csv('X_test_con_nomi.csv', header = 0)
y_test = pd.read_fwf('y_test.txt', header = None)

# %%
with open('activity_labels.txt') as f:
    lines = f.read().splitlines()

# %%
activities = {}
for line in lines:
    label, activity = line.split()
    activities[int(label)] = activity

# %%
# show all columns

pd.set_option("display.max_columns", None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', None)

# %%
X_test
# Out:
#       tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  tBodyAcc-std()-X  \
# 0             -0.023285          -0.014654         -0.938404
# 1             -0.013163          -0.119083         -0.975415
# 2             -0.026050          -0.118152         -0.993819
# 3             -0.032614          -0.117520         -0.994743
# 4             -0.027848          -0.129527         -0.993852
# ...                 ...                ...               ...
# 2942          -0.053391          -0.099109         -0.287866
# 2943          -0.039214          -0.105915         -0.305388
# 2944           0.030077          -0.115788         -0.329638
# 2945           0.018467          -0.096499         -0.323114
# 2946          -0.018437          -0.137018         -0.330046
#
#       tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  tBodyAcc-mad()-Y  \
# 0            -0.920091         -0.667683         -0.952501         -0.925249
# ...

# %%
X_test.columns[0]
# Out:
# 'tBodyAcc-mean()-X'

# %%
X_test=X_test.drop("tBodyAcc-mean()-X",axis=1)

# %%
X_test
# Out:
#       tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  tBodyAcc-std()-X  \
# 0             -0.023285          -0.014654         -0.938404
# 1             -0.013163          -0.119083         -0.975415
# 2             -0.026050          -0.118152         -0.993819
# 3             -0.032614          -0.117520         -0.994743
# 4             -0.027848          -0.129527         -0.993852
# ...                 ...                ...               ...
# 2942          -0.053391          -0.099109         -0.287866
# 2943          -0.039214          -0.105915         -0.305388
# 2944           0.030077          -0.115788         -0.329638
# 2945           0.018467          -0.096499         -0.323114
# 2946          -0.018437          -0.137018         -0.330046
#
#       tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  tBodyAcc-mad()-Y  \
# 0            -0.920091         -0.667683         -0.952501         -0.925249
# ...

# %%
X_train
# Out:
#       tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  tBodyAcc-std()-X  \
# 0             -0.020294          -0.132905         -0.995279
# 1             -0.016411          -0.123520         -0.998245
# 2             -0.019467          -0.113462         -0.995380
# 3             -0.026201          -0.123283         -0.996091
# 4             -0.016570          -0.115362         -0.998139
# ...                 ...                ...               ...
# 7347          -0.057193          -0.181233         -0.195387
# 7348          -0.007749          -0.147468         -0.235309
# 7349          -0.017011          -0.045022         -0.218218
# 7350          -0.018843          -0.158281         -0.219139
# 7351          -0.012423          -0.203867         -0.269270
#
#       tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  tBodyAcc-mad()-Y  \
# 0            -0.983111         -0.913526         -0.995112         -0.983185
# ...

# %%
X_train.columns[0]
# Out:
# 'tBodyAcc-mean()-Y'

# %% [markdown]
# #CLASSIFICATION

# %%
from sklearn.svm import SVC

# %%
bb=SVC(C=0.1, degree=2, gamma='auto', kernel='linear', probability=True)
bb.fit(X_train, y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# SVC(C=0.1, degree=2, gamma='auto', kernel='linear', probability=True)

# %%
def bb_predict(X):
    return bb.predict(X)

def bb_predict_proba(X):
    return bb.predict_proba(X)

# %%
y_pred = bb_predict(X_test)

print('Accuracy %.3f' % accuracy_score(y_test, y_pred))
print("F1-score %s",  f1_score(y_test, y_pred,average=None))
print(classification_report(y_test, y_pred))
# Out:
# Accuracy 0.961
# F1-score %s [0.96945813 0.95605573 0.97101449 0.92842105 0.93967093 1.        ]
#               precision    recall  f1-score   support
#
#            1       0.95      0.99      0.97       496
#            2       0.97      0.95      0.96       471
#            3       0.99      0.96      0.97       420
#            4       0.96      0.90      0.93       491
#            5       0.91      0.97      0.94       532
#            6       1.00      1.00      1.00       537
#
#     accuracy                           0.96      2947
#    macro avg       0.96      0.96      0.96      2947
# weighted avg       0.96      0.96      0.96      2947

# %% [markdown]
# ##LIME

# %%
# !pip install lime

# %%
from lime.lime_tabular import LimeTabularExplainer

# %%
lime_explainer = LimeTabularExplainer(X_test,
                                      feature_names=X_train.columns,
                                      discretize_continuous=False)

# %%
i2e = 4

x = X_test[i2e]

x
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3801             try:
# -> 3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 4
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
exp = lime_explainer.explain_instance(x, bb_predict_proba)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-28-a47104dff917> in <cell line: 1>()
# ----> 1 exp = lime_explainer.explain_instance(x, bb_predict_proba)
#
# NameError: name 'x' is not defined

# %%
exp.local_exp
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-29-5d15168d81b8> in <cell line: 1>()
# ----> 1 exp.local_exp
#
# NameError: name 'exp' is not defined

# %%
exp.show_in_notebook()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-30-7f236c08ce7a> in <cell line: 1>()
# ----> 1 exp.show_in_notebook()
#
# NameError: name 'exp' is not defined

# %% [markdown]
# ##GLOBAL

# %% [markdown]
# CLASSIFICATORE

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import plot_tree

# %%
y_pred_train = bb_predict(X_train)

# %%
y_pred_train = bb_predict(X_train)
explainer = DecisionTreeClassifier(max_depth=8)
explainer.fit(X_train, y_pred_train)
# Out:
# DecisionTreeClassifier(max_depth=8)

# %%
import pydotplus
from sklearn import tree
from IPython.display import Image

# %%
plt.figure(figsize=(14, 10))
plot_tree(explainer,
          feature_names=X_train.columns,
          class_names=None,
          filled=True,
          rounded=True,
          fontsize=12,
          max_depth=2)
plt.show()

# %% [markdown]
# REGRESSORE

# %%
selected_columns = 'tGravityAcc-min()-X'  # Utilizzo una stringa al posto di X_train['tGravityAcc-min()-X']
attributes = [col for col in X_train.columns.tolist() if col != selected_columns]
X = X_train[attributes].values
y = X_train[selected_columns]

# %%
X_train1, X_test1, y_train1, y_test1 = train_test_split(X, y, test_size=0.3, random_state=1000)

# %%
X_test1.shape, y_test1.shape, X_train1.shape, y_train1.shape
# Out:
# ((2206, 538), (2206,), (5146, 538), (5146,))

# %%
y_pred_train = bb_predict(X_train)
# Out:
# X does not have valid feature names, but SVC was fitted with feature names
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-74-b057f0443555> in <cell line: 1>()
# ----> 1 y_pred_train = bb_predict(X_train)
#
# <ipython-input-22-480703e02f98> in bb_predict(X)
#       1 def bb_predict(X):
# ----> 2     return bb.predict(X)
#       3
#       4 def bb_predict_proba(X):
#       5     return bb.predict_proba(X)
#
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py in predict(self, X)
#     818             y = np.argmax(self.decision_function(X), axis=1)
#     819         else:
# --> 820             y = super().predict(X)
#     821         return self.classes_.take(np.asarray(y, dtype=np.intp))
#     822
#
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py in predict(self, X)
#     431             The predicted values.
#     432         """
# ...

# %%
y_pred_train = bb_predict(X_train)
explainer = DecisionTreeClassifier(max_depth=8)
explainer.fit(X_train, y_pred_train)
# Out:
# X does not have valid feature names, but SVC was fitted with feature names
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-75-f4b0e2566f4e> in <cell line: 1>()
# ----> 1 y_pred_train = bb_predict(X_train)
#       2 explainer = DecisionTreeClassifier(max_depth=8)
#       3 explainer.fit(X_train, y_pred_train)
#
# <ipython-input-22-480703e02f98> in bb_predict(X)
#       1 def bb_predict(X):
# ----> 2     return bb.predict(X)
#       3
#       4 def bb_predict_proba(X):
#       5     return bb.predict_proba(X)
#
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py in predict(self, X)
#     818             y = np.argmax(self.decision_function(X), axis=1)
#     819         else:
# --> 820             y = super().predict(X)
#     821         return self.classes_.take(np.asarray(y, dtype=np.intp))
#     822
#
# ...

# %%
plt.figure(figsize=(14, 10))
plot_tree(explainer,
          feature_names=X_train.columns,
          class_names=None,
          filled=True,
          rounded=True,
          fontsize=12,
          max_depth=2)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-67-9bc000abf067> in <cell line: 2>()
#       1 plt.figure(figsize=(14, 10))
#       2 plot_tree(explainer,
# ----> 3           feature_names=X_train.columns,
#       4           class_names=None,
#       5           filled=True,
#
# AttributeError: 'numpy.ndarray' object has no attribute 'columns'

# %% [markdown]
# ##SHAP

# %%
# !pip install shap
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 547.9/547.9 kB 9.1 MB/s eta 0:00:00
# ...

# %%
import shap

shap.initjs()
# Out:
# Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
# ...

# %%
f = lambda x: bb_predict_proba(x)[:, 1]
med = np.median(X_test, axis=0).reshape((1, X_test.shape[1]))

shap_explainer = shap.KernelExplainer(f, med)
# Out:
# X does not have valid feature names, but SVC was fitted with feature names

# %%
i2e = 24

x = X_test[i2e]

x
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3801             try:
# -> 3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 24
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
shap_values_single = shap_explainer.shap_values(x, nsamples=1000)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-51-78dafe51e308> in <cell line: 1>()
# ----> 1 shap_values_single = shap_explainer.shap_values(x, nsamples=1000)
#
# NameError: name 'x' is not defined

# %%
shap_values = shap_explainer.shap_values(X_test[0:100,:], nsamples=1000)

# %%
shap.force_plot(shap_explainer.expected_value, shap_values, X_test[0:100,:], feature_names=df_train.columns)
